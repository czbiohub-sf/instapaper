# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
cons_path = '/Users/jenny.vo-phamhi/Documents/fish_annotation_paper/pipeline_testing/RCA/consensus/ISS_rnd0_ch1_z0/ISS_rnd0_ch1_z0_2.csv'
img_path = '/Users/jenny.vo-phamhi/Documents/fish_annotation_paper/pipeline_testing/RCA/crops/ISS_rnd0_ch1_z0/ISS_rnd0_ch1_z0_2.png'

# %%
cons = np.asarray(pd.read_csv(cons_path))
im = imread(img_path)
im_height = len(im)

# %%
plt.figure()
for x, y in cons:
    plt.scatter([x], [y], edgecolor='blue', facecolor='None')
plt.imshow(im)
plt.show()
